# %%
# %pylab inline

# %%
import dataiku
from dataiku import pandasutils as pdu
import pandas as pd
from bs4 import BeautifulSoup
import re
import pandas as pd
import time
import requests

# %%
class Tabelog:
    """
    食べログスクレイピングクラス
    test_mode=Trueで動作させると、最初のページの３店舗のデータのみを取得できる
    """
    def __init__(self, base_url, test_mode=False, p_ward='東京都内', begin_page=1, end_page=30):

        # 変数宣言
        self.store_id = ''
        self.store_id_num = 0
        self.store_name = ''
        self.score = 0
        self.ward = p_ward
        self.review_cnt = 0
        self.review = ''
        self.review_star = ''
        self.address = ''
        self.columns = ['store_id', 'store_name', 'address', 'score', 'ward', 'review_cnt', 'review', 'review_star']
        self.df = pd.DataFrame(columns=self.columns)
        self.__regexcomp = re.compile(r'\n|\s') # \nは改行、\sは空白

        page_num = begin_page # 店舗一覧ページ番号

        if test_mode:
            list_url = base_url + str(page_num) +  '/?Srt=D&SrtT=rt&sort_mode=1' #食べログの点数ランキングでソートする際に必要な処理
            self.scrape_list(list_url, mode=test_mode)
        else:
            while True:
                list_url = base_url + str(page_num) +  '/?Srt=D&SrtT=rt&sort_mode=1' #食べログの点数ランキングでソートする際に必要な処理
                if self.scrape_list(list_url, mode=test_mode) != True:
                    break

                # INパラメータまでのページ数データを取得する
                if page_num >= end_page:
                    break
                page_num += 1
        return

    def scrape_list(self, list_url, mode):
        """
        店舗一覧ページのパーシング
        """
        r = requests.get(list_url)
        if r.status_code != requests.codes.ok:
            return False

        soup = BeautifulSoup(r.content, 'html.parser')
        soup_a_list = soup.find_all('a', class_='list-rst__rst-name-target') # 店名一覧

        if len(soup_a_list) == 0:
            return False

        if mode:
            for soup_a in soup_a_list[:2]:
                item_url = soup_a.get('href') # 店の個別ページURLを取得
                self.store_id_num += 1
                self.scrape_item(item_url, mode)
        else:
            for soup_a in soup_a_list:
                item_url = soup_a.get('href') # 店の個別ページURLを取得
                self.store_id_num += 1
                self.scrape_item(item_url, mode)

        return True

    def scrape_item(self, item_url, mode):
        """
        個別店舗情報ページのパーシング
        """
        start = time.time()

        r = requests.get(item_url)
        if r.status_code != requests.codes.ok:
            print(f'error:not found{ item_url }')
            return

        soup = BeautifulSoup(r.content, 'html.parser')

        # 店舗名称取得
        # <h2 class="display-name">
        #     <span>
        #         麺匠　竹虎 新宿店
        #     </span>
        # </h2>
        store_name_tag = soup.find('h2', class_='display-name')
        store_name = store_name_tag.span.string
        print('{}→店名：{}'.format(self.store_id_num, store_name.strip()), end='')
        self.store_name = store_name.strip()

        # ラーメン屋、つけ麺屋以外の店舗は除外
        store_head = soup.find('div', class_='rdheader-subinfo') # 店舗情報のヘッダー枠データ取得
        store_head_list = store_head.find_all('dl')
        store_head_list = store_head_list[1].find_all('span')
        #print('ターゲット：', store_head_list[0].text)

        if store_head_list[0].text not in {'ラーメン', 'つけ麺'}:
            print('ラーメンorつけ麺のお店ではないので処理対象外')
            self.store_id_num -= 1
            return

        # 評価点数取得
        #<b class="c-rating__val rdheader-rating__score-val" rel="v:rating">
        #    <span class="rdheader-rating__score-val-dtl">3.58</span>
        #</b>
        rating_score_tag = soup.find('b', class_='c-rating__val')
        rating_score = rating_score_tag.span.string
        print('  評価点数：{}点'.format(rating_score), end='')
        self.score = rating_score

        # 評価点数が存在しない店舗は除外
        if rating_score == '-':
            print('  評価がないため処理対象外')
            self.store_id_num -= 1
            return
       # 評価が3.5未満店舗は除外
        if float(rating_score) < 3.5:
            print('  食べログ評価が3.5未満のため処理対象外')
            self.store_id_num -= 1
            return
        
        # 店の住所を取得
        address_table = soup.find_all('p', class_='rstinfo-table__address')
        address_table = address_table[0]
        address = ''
        for ad in address_table.find_all('span'):
            address += ad.text
        self.address = address

        # レビュー一覧URL取得
        #<a class="mainnavi" href="https://tabelog.com/tokyo/A1304/A130401/13143442/dtlrvwlst/"><span>口コミ</span><span class="rstdtl-navi__total-count"><em>60</em></span></a>
        review_tag_id = soup.find('li', id="rdnavi-review")
        review_tag = review_tag_id.a.get('href')

        # レビュー件数取得
        print('  レビュー件数：{}'.format(review_tag_id.find('span', class_='rstdtl-navi__total-count').em.string), end='')
        self.review_cnt = review_tag_id.find('span', class_='rstdtl-navi__total-count').em.string

        # レビュー一覧ページ番号
        page_num = 1 #1ページ*20 = 20レビュー 。この数字を変えて取得するレビュー数を調整。

        # レビュー一覧ページから個別レビューページを読み込み、パーシング
        # 店舗の全レビューを取得すると、食べログの評価ごとにデータ件数の濃淡が発生してしまうため、
        # 取得するレビュー数は１ページ分としている（件数としては１ページ*20=２0レビュー）
        while True:
            review_url = review_tag + 'COND-0/smp1/?lc=0&rvw_part=all&PG=' + str(page_num)
            #print('\t口コミ一覧リンク：{}'.format(review_url))
            print(' . ' , end='') #LOG
            if self.scrape_review(review_url) != True:
                break
            if page_num >= 1:
                break
            page_num += 1

        process_time = time.time() - start
        print('  取得時間：{}'.format(process_time))

        return

    def scrape_review(self, review_url):
        """
        レビュー一覧ページのパーシング
        """
        r = requests.get(review_url)
        if r.status_code != requests.codes.ok:
            print(f'error:not found{ review_url }')
            return False

        # 各個人の口コミページ詳細へのリンクを取得する
        #<div class="rvw-item js-rvw-item-clickable-area" data-detail-url="/tokyo/A1304/A130401/13141542/dtlrvwlst/B408082636/?use_type=0&amp;smp=1">
        #</div>
        soup = BeautifulSoup(r.content, 'html.parser')
        review_url_list = soup.find_all('div', class_='rvw-item') # 口コミ詳細ページURL一覧

        if len(review_url_list) == 0:
            return False

        for url in review_url_list:
            review_detail_url = 'https://tabelog.com' + url.get('data-detail-url')
            #print('\t口コミURL：', review_detail_url)

            # 口コミのテキストを取得
            self.get_review_text(review_detail_url)

        return True

    def get_review_text(self, review_detail_url):
        """
        口コミ詳細ページをパーシング
        """
        r = requests.get(review_detail_url)
        if r.status_code != requests.codes.ok:
            print(f'error:not found{ review_detail_url }')
            return

        # ２回以上来訪してコメントしているユーザは最新の1件のみを採用
        #<div class="rvw-item__rvw-comment" property="v:description">
        #  <p>
        #    <br>すごい煮干しラーメン凪 新宿ゴールデン街本館<br>スーパーゴールデン1600円（20食限定）を喰らう<br>大盛り無料です<br>スーパーゴールデンは、新宿ゴールデン街にちなんで、ココ本店だけの特別メニューだそうです<br>相方と歌舞伎町のtohoシネマズの映画館でドラゴンボール超ブロリー を観てきた<br>ブロリー 強すぎるね(^^)面白かったです<br>凪の煮干しラーメンも激ウマ<br>いったん麺ちゅるちゅる感に、レアチャーと大トロチャーシューのトロけ具合もうめえ<br>煮干しスープもさすが！と言うほど完成度が高い<br>さすが食べログラーメン百名店<br>と言うか<br>2日連チャンで、近場の食べログラーメン百名店のうちの2店舗、昨日の中華そば葉山さんと今日の凪<br>静岡では考えられん笑笑<br>ごちそうさまでした
        #  </p>
        #</div>
        soup = BeautifulSoup(r.content, 'html.parser')
        review = soup.find_all('div', class_='rvw-item__rvw-comment')#reviewが含まれているタグの中身をすべて取得
        if len(review) == 0:
            review = ''
        else:
            review = review[0].p.text.strip() # strip()は改行コードを除外する関数
        
        # 各レビューの★の数を取得
        review_star = soup.find_all('b', class_='c-rating-v2__val c-rating-v2__val--strong rvw-item__ratings--val')
        if len(review_star) == 0:
            review_star = ''
        else:
            review_star = review_star[0].string

        #print('\t\t口コミテキスト：', review)
        self.review = review
        self.review_star = review_star

        # データフレームの生成
        self.make_df()
        return

    def make_df(self):
        self.store_id = str(self.store_id_num).zfill(8) #0パディング
        se = pd.Series([self.store_id, self.store_name, self.address, self.score, self.ward, self.review_cnt, self.review, self.review_star], self.columns) # 行を作成
        self.df = self.df.append(se, self.columns) # データフレームに行を追加
        return

# %%
tokyo_ramen_review = Tabelog(base_url="https://tabelog.com/tokyo/rstLst/ramen/",test_mode=True, p_ward='東京都内')
# Out:
# 1→店名：手打式超多加水麺 ののくら  評価点数：3.98点  レビュー件数：479 .   取得時間：69.15089106559753
# 2→店名：Homemade Ramen 麦苗  評価点数：3.97点  レビュー件数：731 .   取得時間：88.36260294914246

# %%
tokyo_ramen_review.df
# Out:
#     store_id         store_name                      address score  ward review_cnt                                             review review_star
# 0   00000001      手打式超多加水麺 ののくら  東京都葛飾区亀有3-11-11マーベラス大協ビル 1F  3.98  東京都内        479  2020年、ラーメン103杯目(^^)本日、朝イチで営業を済ませ、次の打ち合わせまで時間が空...         4.8
# 1   00000001      手打式超多加水麺 ののくら  東京都葛飾区亀有3-11-11マーベラス大協ビル 1F  3.98  東京都内        479  ミシュラン東京2019　ビルグルマン受賞店の「手打式超多加水麺　ののくら」さんに伺いました。...         3.8
# 2   00000001      手打式超多加水麺 ののくら  東京都葛飾区亀有3-11-11マーベラス大協ビル 1F  3.98  東京都内        479  平日の13時過ぎに伺いました＼(^o^)／駅から少し歩いた通り沿いにあり、外観はシンプル落ち...         3.8
# 3   00000001      手打式超多加水麺 ののくら  東京都葛飾区亀有3-11-11マーベラス大協ビル 1F  3.98  東京都内        479  食べログ100名店簡単にお店の場所:亀有駅に着いて、両さんがお出迎え、南口から徒歩5分くらい...         3.8
# 4   00000001      手打式超多加水麺 ののくら  東京都葛飾区亀有3-11-11マーベラス大協ビル 1F  3.98  東京都内        479  エグい行列が嫌でしばらく行ってませんでしたが、土曜日の「記帳予約制」なる制度が始まったので久...         4.5
# 5   00000001      手打式超多加水麺 ののくら  東京都葛飾区亀有3-11-11マーベラス大協ビル 1F  3.98  東京都内        479  亀有に用事が有り、早目に着いたので、前から行きたかった人気店の『手打式超多加水麺 ののくら』...         4.1
# 6   00000001      手打式超多加水麺 ののくら  東京都葛飾区亀有3-11-11マーベラス大協ビル 1F  3.98  東京都内        479  朝イチ仕事で亀有に行くことになった。仕事で亀有に行くのは初めてのこと。私用でもまず行かないの...         3.9
# 7   00000001      手打式超多加水麺 ののくら  東京都葛飾区亀有3-11-11マーベラス大協ビル 1F  3.98  東京都内        479  今日のお昼は、ミシュランガイド東京のビブグルマンに掲載された手打式超多加水麺ののくら。昼営業...         4.3
# 8   00000001      手打式超多加水麺 ののくら  東京都葛飾区亀有3-11-11マーベラス大協ビル 1F  3.98  東京都内        479  久しぶりにののくらさんに行って来ました。言わずと知れたラーメンの百名店さんです。駅から歩いて...         3.8
# 9   00000001      手打式超多加水麺 ののくら  東京都葛飾区亀有3-11-11マーベラス大協ビル 1F  3.98  東京都内        479  2021年3月現在、東京のラーメンランキング1位とのことで期待しつつ来店。平日でも開店前から...         3.2
# 10  00000001      手打式超多加水麺 ののくら  東京都葛飾区亀有3-11-11マーベラス大協ビル 1F  3.98  東京都内        479  平日の１２：３０で「ヤバいかな」と思いながら伺うと３０人を超える大行列。。隣のマンションを越...         4.2
# 11  00000001      手打式超多加水麺 ののくら  東京都葛飾区亀有3-11-11マーベラス大協ビル 1F  3.98  東京都内        479  念願の初来店(有休とりました笑)平日金曜10:20着、既に約25人の行列…11:00開店時に...         4.5
# 12  00000001      手打式超多加水麺 ののくら  東京都葛飾区亀有3-11-11マーベラス大協ビル 1F  3.98  東京都内        479  《食べログブロンズランキング》評価：3.98《2021 Tabelog Bronze Awa...         3.5
# 13  00000001      手打式超多加水麺 ののくら  東京都葛飾区亀有3-11-11マーベラス大協ビル 1F  3.98  東京都内        479  亀有のラーメン屋。亀有駅から歩いて5分ほどの場所にあります。全国ラーメンランキングTOP3に...         4.0
# 14  00000001      手打式超多加水麺 ののくら  東京都葛飾区亀有3-11-11マーベラス大協ビル 1F  3.98  東京都内        479  【アクセス】JR亀有駅から徒歩で５分くらいのところ、きらぼし銀行の前に拉麺屋さんはあります。...         4.2
# 15  00000001      手打式超多加水麺 ののくら  東京都葛飾区亀有3-11-11マーベラス大協ビル 1F  3.98  東京都内        479  亀有駅から徒歩4分のお店。11時オープンで、11時10分ぐらいに到着。すでに35人ぐらい並ん...         3.8
# 16  00000001      手打式超多加水麺 ののくら  東京都葛飾区亀有3-11-11マーベラス大協ビル 1F  3.98  東京都内        479  事前リサーチ完璧。並び2時間覚悟の完全防備でいよいよ、「超高加水麺ののくら」さんに突撃してき...         4.0
# 17  00000001      手打式超多加水麺 ののくら  東京都葛飾区亀有3-11-11マーベラス大協ビル 1F  3.98  東京都内        479  ラーメンは何と言っても「醤油」が好き。日本で最も醤油を作ってる千葉県で育ちましたから。食べロ...         5.0
# 18  00000001      手打式超多加水麺 ののくら  東京都葛飾区亀有3-11-11マーベラス大協ビル 1F  3.98  東京都内        479  平日の昼前33人待ち⚠️食券買ってから並ぶ※並んでるうちに材料切れ終了の場合ある為※この日は...         4.1
# 19  00000001      手打式超多加水麺 ののくら  東京都葛飾区亀有3-11-11マーベラス大協ビル 1F  3.98  東京都内        479                             亀有の最高峰の醤油ラーメン。一見の価値あり。         4.8
# 20  00000001      手打式超多加水麺 ののくら  東京都葛飾区亀有3-11-11マーベラス大協ビル 1F  3.98  東京都内        479  （味の感想は★からです）亀有の町に降り立つ。東京都葛飾区亀有。言わずと知れた「こち亀」の聖地...         4.8
# 21  00000001      手打式超多加水麺 ののくら  東京都葛飾区亀有3-11-11マーベラス大協ビル 1F  3.98  東京都内        479  2021年1月    手打式超多加水麺　ののくらこの日は、亀有の「手打式超多加水麺　ののくら...         3.6
# 22  00000002  Homemade Ramen 麦苗             東京都品川区南大井6-11-10  3.97  東京都内        731  2020/08/03(月)5度目の訪問！現在は蜜を避けるために、事前記帳(予約)式になってい...         4.0
# 23  00000002  Homemade Ramen 麦苗             東京都品川区南大井6-11-10  3.97  東京都内        731  2020年1月平日、10:15往訪。10:30から受付開始であり、その15分前に到着。ざっと...         4.4
# 24  00000002  Homemade Ramen 麦苗             東京都品川区南大井6-11-10  3.97  東京都内        731  ＜＜ミシュラン・ビブグルマン４年連続の名店＞＞こちらは、２０１６年の開店時から東京・大森駅か...         4.4
# 25  00000002  Homemade Ramen 麦苗             東京都品川区南大井6-11-10  3.97  東京都内        731  Instagram    pateknautilus40https://www.instag...         4.0
# 26  00000002  Homemade Ramen 麦苗             東京都品川区南大井6-11-10  3.97  東京都内        731  無化調ラーメンに最高の極上チャーシューとラーメン屋のレベルを超えたサイドメニューは、ここでし...         4.8
# 27  00000002  Homemade Ramen 麦苗             東京都品川区南大井6-11-10  3.97  東京都内        731  平日火曜日、11時45分にお店へ到着。すぐに記帳表を見つけ、手前の空きを探すものの13時15...         3.9
# 28  00000002  Homemade Ramen 麦苗             東京都品川区南大井6-11-10  3.97  東京都内        731  とんでもなく評価の高いラーメン店。訪問来店度が高いと思っていたが、意外にも時間帯によってはす...         4.5
# 29  00000002  Homemade Ramen 麦苗             東京都品川区南大井6-11-10  3.97  東京都内        731  特上 生姜醤油　　　　　　　　　　　172月12日、今日の昼食は麦苗です。平日なので10時に...         4.8
# 30  00000002  Homemade Ramen 麦苗             東京都品川区南大井6-11-10  3.97  東京都内        731  2021年の麦苗初め。日曜日なので気合入れて9時前に到着して、ウェイティングのボードが出るの...         4.1
# 31  00000002  Homemade Ramen 麦苗             東京都品川区南大井6-11-10  3.97  東京都内        731  あれよあれよと一年ぶりです。土曜日の朝、しんどいのを振り切って「麦苗」さんに訪問です。08時...         4.2
# 32  00000002  Homemade Ramen 麦苗             東京都品川区南大井6-11-10  3.97  東京都内        731  大森駅から歩いて数分のところにあります。全国トップクラスのラーメン屋さん。2021年ミシュラ...         4.1
# 33  00000002  Homemade Ramen 麦苗             東京都品川区南大井6-11-10  3.97  東京都内        731  美味しいラーメン屋さん？と聞かれれば迷うことなくこちらを激推しします。現在は記帳制で、密にな...         4.8
# 34  00000002  Homemade Ramen 麦苗             東京都品川区南大井6-11-10  3.97  東京都内        731  《店舗情報》2016年4月23日にオープンして瞬く間に超行列店になった『Homemade R...         3.6
# 35  00000002  Homemade Ramen 麦苗             東京都品川区南大井6-11-10  3.97  東京都内        731  私はラーメンが好きであっちこっちに出没しては、人気のお店を訪ね歩いています。日本人はラーメン...         4.5
# 36  00000002  Homemade Ramen 麦苗             東京都品川区南大井6-11-10  3.97  東京都内        731  私の場合「ラーメン」というワードは即ち「麦苗」というワードに脳内変換される。朝9時に店頭...         5.0
# 37  00000002  Homemade Ramen 麦苗             東京都品川区南大井6-11-10  3.97  東京都内        731  私の活動範囲ではないので、足が向きませんでしたが、数日前にTwitterのフォロワーとなりま...         4.4
# 38  00000002  Homemade Ramen 麦苗             東京都品川区南大井6-11-10  3.97  東京都内        731  日時:火曜、15時頃予約:あり(2時間前、記帳)待ち:なし人数:1人座席:カウンター頻度:初...         4.3
# 39  00000002  Homemade Ramen 麦苗             東京都品川区南大井6-11-10  3.97  東京都内        731  平日の休みを利用して久々に訪問、9時前に一回並んで、名前を書いて指定時間に再訪問という、近く...         4.2
# 40  00000002  Homemade Ramen 麦苗             東京都品川区南大井6-11-10  3.97  東京都内        731  1月3日の麦苗は鯛を使ったスペシャルバージョンのラーメン(1300円)プラス特別セット(50...         4.8
# 41  00000002  Homemade Ramen 麦苗             東京都品川区南大井6-11-10  3.97  東京都内        731  〜レアチャーシューをもとめて〜令和2年12月29日平日朝8時45分には約30人以上の行列8時...         4.5
# 42  00000002  Homemade Ramen 麦苗             東京都品川区南大井6-11-10  3.97  東京都内        731  年の暮れ、めったに行かない大森へ。遅めのランチができる場所をチェックしたところ、一際高評価の...         3.7
# 43  00000002  Homemade Ramen 麦苗             東京都品川区南大井6-11-10  3.97  東京都内        731  平日のお昼を回った午後2時ごろにお邪魔しました。昼時をすぎているにもかかわらず、外には約10...         4.3
